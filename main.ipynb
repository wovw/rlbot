# %%
# simple example

import rlgym

env = rlgym.make()

while True:
    obs = env.reset()
    done = False

    while not done:
      # Here we sample a random action. If you have an agent, you would get an action from it here.
      action = env.action_space.sample()

      next_obs, reward, done, gameinfo = env.step(action)

      obs = next_obs
# Out:
# Version 1.2.2
#
#     - Fixed max python version
#
#
# Launching Rocket League, make sure bakkesmod is running.
# Launched Steam version
# Receive message failed
# RLGym has encountered an exception!
# Exception traceback:
# Traceback (most recent call last):
#   File "<string>", line 2, in __init__
# KeyboardInterrupt
#
# EXCEPTION ARGS: ()
# !ROCKET LEAGUE HAS CRASHED!
# ATTEMPTING RECOVERY
# Discovered 1 existing Rocket League processes. Waiting 2 seconds before attempting to open a new one.
# Launching Rocket League, make sure bakkesmod is running.
# Launched Steam version
# c:\Users\sasia\envs\RL\lib\site-packages\pywinauto\__init__.py:71: UserWarning: Apply externally defined coinit_flags: 0
#   warnings.warn("Apply externally defined coinit_flags: {0}"

# %%
# single-instance example

# import the gym and stable baselines 3 libraries
import rlgym
from stable_baselines3.ppo import PPO
from rlgym_tools.sb3_utils import SB3SingleInstanceEnv

# setup the RLGym environment
gym_env = rlgym.make(use_injector=True, self_play=True)

# wrap the RLGym environment with the single instance wrapper
env = SB3SingleInstanceEnv(gym_env)

# create a PPO instance and start learning
learner = PPO(policy="MlpPolicy", env=env, verbose=1)
learner.learn(1_000_000)
env.close()
# Out:
# C:\Users\sasia\AppData\Local\Temp\ipykernel_28628\4050329745.py:9: DeprecationWarning: self_play argument is deprecated and will be removed in future rlgym versions.
# Please use spawn_opponents instead
#   gym_env = rlgym.make(use_injector=True, self_play=True)
# Version 1.2.2
#
#     - Fixed max python version
#
#
# Launching Rocket League, make sure bakkesmod is running.
# Launched Epic version
# Executing injector...
# Using cuda device
# -----------------------------
# | time/              |      |
# |    fps             | 452  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 4096 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 422         |
# |    iterations           | 2           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009110077 |
# |    clip_fraction        | 0.0791      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.3       |
# |    explained_variance   | 0.000648    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.48e+03    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0147     |
# |    std                  | 0.998       |
# |    value_loss           | 1.36e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 415         |
# |    iterations           | 3           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.007972329 |
# |    clip_fraction        | 0.0554      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.3       |
# |    explained_variance   | 4.64e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.02e+03    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0135     |
# |    std                  | 0.999       |
# |    value_loss           | 1.17e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 411         |
# |    iterations           | 4           |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.010076532 |
# |    clip_fraction        | 0.0952      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.4       |
# |    explained_variance   | 2.66e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.34e+03    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0163     |
# |    std                  | 1           |
# |    value_loss           | 1.19e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 405         |
# |    iterations           | 5           |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.010182556 |
# |    clip_fraction        | 0.0943      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.4       |
# |    explained_variance   | 1.03e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.43e+03    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0174     |
# |    std                  | 1           |
# |    value_loss           | 1.18e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 403         |
# |    iterations           | 6           |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.011131512 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.3       |
# |    explained_variance   | 6.68e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.75e+03    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0178     |
# |    std                  | 0.996       |
# |    value_loss           | 1.08e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 400         |
# |    iterations           | 7           |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.009859921 |
# |    clip_fraction        | 0.0837      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.3       |
# |    explained_variance   | 3.64e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.12e+03    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0167     |
# |    std                  | 0.997       |
# |    value_loss           | 9.03e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 401         |
# |    iterations           | 8           |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.010494355 |
# |    clip_fraction        | 0.0991      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.3       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.14e+03    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0193     |
# |    std                  | 0.995       |
# |    value_loss           | 9.42e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 397         |
# |    iterations           | 9           |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.012780275 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.3       |
# |    explained_variance   | 1.43e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.38e+03    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.019      |
# |    std                  | 0.994       |
# |    value_loss           | 1e+04       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 394         |
# |    iterations           | 10          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.013174238 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.3       |
# |    explained_variance   | 9.54e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.75e+03    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0208     |
# |    std                  | 0.998       |
# |    value_loss           | 8.98e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 395         |
# |    iterations           | 11          |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.012879051 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.3       |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.4e+03     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0226     |
# |    std                  | 0.993       |
# |    value_loss           | 7.98e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 396         |
# |    iterations           | 12          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.011857652 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.3       |
# |    explained_variance   | 3.58e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.77e+03    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0192     |
# |    std                  | 0.992       |
# |    value_loss           | 9.42e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 396         |
# |    iterations           | 13          |
# |    time_elapsed         | 134         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.012872417 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.3       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.97e+03    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0214     |
# |    std                  | 0.989       |
# |    value_loss           | 5.73e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 396         |
# |    iterations           | 14          |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.014078721 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.3       |
# |    explained_variance   | 2.98e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.6e+03     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0226     |
# |    std                  | 0.988       |
# |    value_loss           | 5.94e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 397         |
# |    iterations           | 15          |
# |    time_elapsed         | 154         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.014070947 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.2       |
# |    explained_variance   | 2.38e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.27e+03    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0219     |
# |    std                  | 0.983       |
# |    value_loss           | 7.54e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 398         |
# |    iterations           | 16          |
# |    time_elapsed         | 164         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.014674084 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.2       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.09e+03    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0225     |
# |    std                  | 0.982       |
# |    value_loss           | 5.56e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 398         |
# |    iterations           | 17          |
# |    time_elapsed         | 174         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.018240666 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.2       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.11e+03    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0241     |
# |    std                  | 0.979       |
# |    value_loss           | 4.92e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 399         |
# |    iterations           | 18          |
# |    time_elapsed         | 184         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.016212754 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.1       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.15e+03    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0239     |
# |    std                  | 0.973       |
# |    value_loss           | 6.32e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 399         |
# |    iterations           | 19          |
# |    time_elapsed         | 194         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.016700067 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.1       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.7e+03     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0231     |
# |    std                  | 0.971       |
# |    value_loss           | 5.64e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 400         |
# |    iterations           | 20          |
# |    time_elapsed         | 204         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.018358583 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.1       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.68e+03    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0247     |
# |    std                  | 0.967       |
# |    value_loss           | 5.37e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 400         |
# |    iterations           | 21          |
# |    time_elapsed         | 214         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.016122764 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.1       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.27e+03    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0247     |
# |    std                  | 0.964       |
# |    value_loss           | 5.99e+03    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 400        |
# |    iterations           | 22         |
# |    time_elapsed         | 224        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.03571593 |
# |    clip_fraction        | 0.362      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -11        |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.31e+03   |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.00102   |
# |    std                  | 0.957      |
# |    value_loss           | 4.51e+03   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 400         |
# |    iterations           | 23          |
# |    time_elapsed         | 234         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.014691077 |
# |    clip_fraction        | 0.0971      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11         |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.16e+03    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0161     |
# |    std                  | 0.955       |
# |    value_loss           | 6.08e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 401         |
# |    iterations           | 24          |
# |    time_elapsed         | 244         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.031388726 |
# |    clip_fraction        | 0.365       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11         |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.82e+03    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.000863   |
# |    std                  | 0.954       |
# |    value_loss           | 4.98e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 402         |
# |    iterations           | 25          |
# |    time_elapsed         | 254         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.025692547 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11         |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.85e+03    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00529    |
# |    std                  | 0.953       |
# |    value_loss           | 6.86e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 402         |
# |    iterations           | 26          |
# |    time_elapsed         | 264         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.023874868 |
# |    clip_fraction        | 0.342       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.9       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.81e+03    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | 0.000372    |
# |    std                  | 0.944       |
# |    value_loss           | 6.21e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 403         |
# |    iterations           | 27          |
# |    time_elapsed         | 274         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.025324594 |
# |    clip_fraction        | 0.306       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.9       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.52e+03    |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00322    |
# |    std                  | 0.945       |
# |    value_loss           | 5.97e+03    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 403        |
# |    iterations           | 28         |
# |    time_elapsed         | 284        |
# |    total_timesteps      | 114688     |
# | train/                  |            |
# |    approx_kl            | 0.02672084 |
# |    clip_fraction        | 0.296      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -10.9      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.21e+03   |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.0106    |
# |    std                  | 0.942      |
# |    value_loss           | 6.02e+03   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 404         |
# |    iterations           | 29          |
# |    time_elapsed         | 293         |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.016957305 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.8       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.87e+03    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0107     |
# |    std                  | 0.939       |
# |    value_loss           | 7.75e+03    |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 404       |
# |    iterations           | 30        |
# |    time_elapsed         | 303       |
# |    total_timesteps      | 122880    |
# | train/                  |           |
# |    approx_kl            | 0.0261715 |
# |    clip_fraction        | 0.338     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -10.8     |
# |    explained_variance   | 1.79e-07  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.52e+03  |
# |    n_updates            | 290       |
# |    policy_gradient_loss | -0.00822  |
# |    std                  | 0.938     |
# |    value_loss           | 5.14e+03  |
# ---------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 404          |
# |    iterations           | 31           |
# |    time_elapsed         | 313          |
# |    total_timesteps      | 126976       |
# | train/                  |              |
# |    approx_kl            | 0.0043652076 |
# |    clip_fraction        | 0.00857      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.8        |
# |    explained_variance   | 0.109        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.59e+03     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00651     |
# |    std                  | 0.938        |
# |    value_loss           | 5.09e+03     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 405         |
# |    iterations           | 32          |
# |    time_elapsed         | 323         |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.002609368 |
# |    clip_fraction        | 0.00139     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.8       |
# |    explained_variance   | 0.3         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.67e+03    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00407    |
# |    std                  | 0.938       |
# |    value_loss           | 5.04e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 405         |
# |    iterations           | 33          |
# |    time_elapsed         | 332         |
# |    total_timesteps      | 135168      |
# | train/                  |             |
# |    approx_kl            | 0.002651749 |
# |    clip_fraction        | 0.00146     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.8       |
# |    explained_variance   | 0.428       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.57e+03    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00377    |
# |    std                  | 0.938       |
# |    value_loss           | 5.87e+03    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 406          |
# |    iterations           | 34           |
# |    time_elapsed         | 342          |
# |    total_timesteps      | 139264       |
# | train/                  |              |
# |    approx_kl            | 0.0047179926 |
# |    clip_fraction        | 0.0135       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.8        |
# |    explained_variance   | 0.132        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 996          |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00567     |
# |    std                  | 0.938        |
# |    value_loss           | 4.4e+03      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 405          |
# |    iterations           | 35           |
# |    time_elapsed         | 353          |
# |    total_timesteps      | 143360       |
# | train/                  |              |
# |    approx_kl            | 0.0048488295 |
# |    clip_fraction        | 0.0217       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.8        |
# |    explained_variance   | 0.34         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.94e+03     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00668     |
# |    std                  | 0.936        |
# |    value_loss           | 3.88e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 405          |
# |    iterations           | 36           |
# |    time_elapsed         | 363          |
# |    total_timesteps      | 147456       |
# | train/                  |              |
# |    approx_kl            | 0.0039720302 |
# |    clip_fraction        | 0.00896      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.8        |
# |    explained_variance   | 0.421        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 918          |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00553     |
# |    std                  | 0.936        |
# |    value_loss           | 3.92e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 406          |
# |    iterations           | 37           |
# |    time_elapsed         | 373          |
# |    total_timesteps      | 151552       |
# | train/                  |              |
# |    approx_kl            | 0.0058755553 |
# |    clip_fraction        | 0.0394       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.8        |
# |    explained_variance   | 0.156        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.45e+03     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00928     |
# |    std                  | 0.937        |
# |    value_loss           | 3.72e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 406          |
# |    iterations           | 38           |
# |    time_elapsed         | 383          |
# |    total_timesteps      | 155648       |
# | train/                  |              |
# |    approx_kl            | 0.0055917706 |
# |    clip_fraction        | 0.0359       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.8        |
# |    explained_variance   | 0.44         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.25e+03     |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.0093      |
# |    std                  | 0.936        |
# |    value_loss           | 3.21e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 406          |
# |    iterations           | 39           |
# |    time_elapsed         | 393          |
# |    total_timesteps      | 159744       |
# | train/                  |              |
# |    approx_kl            | 0.0048864805 |
# |    clip_fraction        | 0.0162       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.8        |
# |    explained_variance   | 0.32         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.25e+03     |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00958     |
# |    std                  | 0.934        |
# |    value_loss           | 2.62e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 406          |
# |    iterations           | 40           |
# |    time_elapsed         | 402          |
# |    total_timesteps      | 163840       |
# | train/                  |              |
# |    approx_kl            | 0.0052866465 |
# |    clip_fraction        | 0.0326       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.8        |
# |    explained_variance   | 0.458        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.29e+03     |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.0116      |
# |    std                  | 0.932        |
# |    value_loss           | 3.42e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 406          |
# |    iterations           | 41           |
# |    time_elapsed         | 412          |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0067148334 |
# |    clip_fraction        | 0.0427       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.8        |
# |    explained_variance   | 0.51         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.75e+03     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.0113      |
# |    std                  | 0.933        |
# |    value_loss           | 2.91e+03     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 406         |
# |    iterations           | 42          |
# |    time_elapsed         | 422         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.007127391 |
# |    clip_fraction        | 0.0529      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.8       |
# |    explained_variance   | 0.238       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.06e+03    |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0135     |
# |    std                  | 0.935       |
# |    value_loss           | 2.84e+03    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 407          |
# |    iterations           | 43           |
# |    time_elapsed         | 432          |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0077988748 |
# |    clip_fraction        | 0.0707       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.8        |
# |    explained_variance   | 0.394        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 927          |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.0148      |
# |    std                  | 0.932        |
# |    value_loss           | 2.24e+03     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 407         |
# |    iterations           | 44          |
# |    time_elapsed         | 442         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.008004026 |
# |    clip_fraction        | 0.0582      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.7       |
# |    explained_variance   | 0.451       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 764         |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0145     |
# |    std                  | 0.928       |
# |    value_loss           | 2.53e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 407         |
# |    iterations           | 45          |
# |    time_elapsed         | 452         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.010869951 |
# |    clip_fraction        | 0.0823      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.7       |
# |    explained_variance   | 0.532       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 613         |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.015      |
# |    std                  | 0.926       |
# |    value_loss           | 1.71e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 407         |
# |    iterations           | 46          |
# |    time_elapsed         | 462         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.011974515 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.7       |
# |    explained_variance   | 0.525       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 750         |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0182     |
# |    std                  | 0.917       |
# |    value_loss           | 1.52e+03    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 407        |
# |    iterations           | 47         |
# |    time_elapsed         | 472        |
# |    total_timesteps      | 192512     |
# | train/                  |            |
# |    approx_kl            | 0.01140302 |
# |    clip_fraction        | 0.117      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -10.6      |
# |    explained_variance   | 0.666      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 576        |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.0172    |
# |    std                  | 0.916      |
# |    value_loss           | 1.28e+03   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 407         |
# |    iterations           | 48          |
# |    time_elapsed         | 482         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.009490946 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.6       |
# |    explained_variance   | 0.487       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 452         |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0144     |
# |    std                  | 0.914       |
# |    value_loss           | 1.4e+03     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 407         |
# |    iterations           | 49          |
# |    time_elapsed         | 492         |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.011198504 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.5       |
# |    explained_variance   | 0.65        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 438         |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0176     |
# |    std                  | 0.906       |
# |    value_loss           | 1.14e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 408         |
# |    iterations           | 50          |
# |    time_elapsed         | 501         |
# |    total_timesteps      | 204800      |
# | train/                  |             |
# |    approx_kl            | 0.010240518 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.5       |
# |    explained_variance   | 0.57        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 257         |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0151     |
# |    std                  | 0.901       |
# |    value_loss           | 785         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 408         |
# |    iterations           | 51          |
# |    time_elapsed         | 511         |
# |    total_timesteps      | 208896      |
# | train/                  |             |
# |    approx_kl            | 0.011467299 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.4       |
# |    explained_variance   | 0.456       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 462         |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0163     |
# |    std                  | 0.895       |
# |    value_loss           | 1.22e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 408         |
# |    iterations           | 52          |
# |    time_elapsed         | 521         |
# |    total_timesteps      | 212992      |
# | train/                  |             |
# |    approx_kl            | 0.012932274 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.4       |
# |    explained_variance   | 0.67        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 307         |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0139     |
# |    std                  | 0.89        |
# |    value_loss           | 700         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 408         |
# |    iterations           | 53          |
# |    time_elapsed         | 531         |
# |    total_timesteps      | 217088      |
# | train/                  |             |
# |    approx_kl            | 0.012373764 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.3       |
# |    explained_variance   | 0.668       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 191         |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0165     |
# |    std                  | 0.887       |
# |    value_loss           | 503         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 407         |
# |    iterations           | 54          |
# |    time_elapsed         | 542         |
# |    total_timesteps      | 221184      |
# | train/                  |             |
# |    approx_kl            | 0.013476916 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.3       |
# |    explained_variance   | 0.715       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 331         |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.0134     |
# |    std                  | 0.88        |
# |    value_loss           | 484         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 408          |
# |    iterations           | 55           |
# |    time_elapsed         | 551          |
# |    total_timesteps      | 225280       |
# | train/                  |              |
# |    approx_kl            | 0.0149092665 |
# |    clip_fraction        | 0.149        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.3        |
# |    explained_variance   | 0.686        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 90.1         |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.0153      |
# |    std                  | 0.878        |
# |    value_loss           | 389          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 408         |
# |    iterations           | 56          |
# |    time_elapsed         | 561         |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.014784306 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.2       |
# |    explained_variance   | 0.78        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 70.4        |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.0167     |
# |    std                  | 0.874       |
# |    value_loss           | 260         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 408         |
# |    iterations           | 57          |
# |    time_elapsed         | 571         |
# |    total_timesteps      | 233472      |
# | train/                  |             |
# |    approx_kl            | 0.013667781 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.2       |
# |    explained_variance   | 0.756       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 66.8        |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.00886    |
# |    std                  | 0.868       |
# |    value_loss           | 258         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 408        |
# |    iterations           | 58         |
# |    time_elapsed         | 582        |
# |    total_timesteps      | 237568     |
# | train/                  |            |
# |    approx_kl            | 0.01328363 |
# |    clip_fraction        | 0.155      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -10.1      |
# |    explained_variance   | 0.788      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 68.1       |
# |    n_updates            | 570        |
# |    policy_gradient_loss | -0.0109    |
# |    std                  | 0.867      |
# |    value_loss           | 235        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 408         |
# |    iterations           | 59          |
# |    time_elapsed         | 592         |
# |    total_timesteps      | 241664      |
# | train/                  |             |
# |    approx_kl            | 0.014796766 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.1       |
# |    explained_variance   | 0.783       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.9        |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.0125     |
# |    std                  | 0.87        |
# |    value_loss           | 177         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 408         |
# |    iterations           | 60          |
# |    time_elapsed         | 602         |
# |    total_timesteps      | 245760      |
# | train/                  |             |
# |    approx_kl            | 0.011660302 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.1       |
# |    explained_variance   | 0.708       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 85.6        |
# |    n_updates            | 590         |
# |    policy_gradient_loss | -0.0113     |
# |    std                  | 0.863       |
# |    value_loss           | 205         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 408         |
# |    iterations           | 61          |
# |    time_elapsed         | 611         |
# |    total_timesteps      | 249856      |
# | train/                  |             |
# |    approx_kl            | 0.014577331 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.1       |
# |    explained_variance   | 0.703       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 56.6        |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.0126     |
# |    std                  | 0.863       |
# |    value_loss           | 187         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 408         |
# |    iterations           | 62          |
# |    time_elapsed         | 621         |
# |    total_timesteps      | 253952      |
# | train/                  |             |
# |    approx_kl            | 0.016275723 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.1       |
# |    explained_variance   | 0.809       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39.5        |
# |    n_updates            | 610         |
# |    policy_gradient_loss | -0.00808    |
# |    std                  | 0.86        |
# |    value_loss           | 146         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 408         |
# |    iterations           | 63          |
# |    time_elapsed         | 631         |
# |    total_timesteps      | 258048      |
# | train/                  |             |
# |    approx_kl            | 0.015031159 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10         |
# |    explained_variance   | 0.835       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 114         |
# |    n_updates            | 620         |
# |    policy_gradient_loss | -0.0098     |
# |    std                  | 0.852       |
# |    value_loss           | 121         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 408         |
# |    iterations           | 64          |
# |    time_elapsed         | 642         |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.014612582 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.95       |
# |    explained_variance   | 0.748       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 45.8        |
# |    n_updates            | 630         |
# |    policy_gradient_loss | -0.0129     |
# |    std                  | 0.849       |
# |    value_loss           | 152         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 408         |
# |    iterations           | 65          |
# |    time_elapsed         | 652         |
# |    total_timesteps      | 266240      |
# | train/                  |             |
# |    approx_kl            | 0.017207906 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.9        |
# |    explained_variance   | 0.756       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 53.7        |
# |    n_updates            | 640         |
# |    policy_gradient_loss | -0.0143     |
# |    std                  | 0.842       |
# |    value_loss           | 141         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 408         |
# |    iterations           | 66          |
# |    time_elapsed         | 662         |
# |    total_timesteps      | 270336      |
# | train/                  |             |
# |    approx_kl            | 0.015442208 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.84       |
# |    explained_variance   | 0.848       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21          |
# |    n_updates            | 650         |
# |    policy_gradient_loss | -0.0119     |
# |    std                  | 0.838       |
# |    value_loss           | 68.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 408         |
# |    iterations           | 67          |
# |    time_elapsed         | 672         |
# |    total_timesteps      | 274432      |
# | train/                  |             |
# |    approx_kl            | 0.013042804 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.8        |
# |    explained_variance   | 0.849       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.4        |
# |    n_updates            | 660         |
# |    policy_gradient_loss | -0.00986    |
# |    std                  | 0.833       |
# |    value_loss           | 78.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 408         |
# |    iterations           | 68          |
# |    time_elapsed         | 681         |
# |    total_timesteps      | 278528      |
# | train/                  |             |
# |    approx_kl            | 0.017056856 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.76       |
# |    explained_variance   | 0.882       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.3        |
# |    n_updates            | 670         |
# |    policy_gradient_loss | -0.0072     |
# |    std                  | 0.831       |
# |    value_loss           | 38.1        |
# -----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 16
#      14 # create a PPO instance and start learning
#      15 learner = PPO(policy="MlpPolicy", env=env, verbose=1)
# ---> 16 learner.learn(1_000_000)
#      17 env.close()
#
# File c:\Users\sasia\envs\RL\lib\site-packages\stable_baselines3\ppo\ppo.py:308, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     299 def learn(
#     300     self: SelfPPO,
#     301     total_timesteps: int,
#    (...)
#     306     progress_bar: bool = False,
#     307 ) -> SelfPPO:
# --> 308     return super().learn(
#     309         total_timesteps=total_timesteps,
#     310         callback=callback,
#     311         log_interval=log_interval,
#     312         tb_log_name=tb_log_name,
#     313         reset_num_timesteps=reset_num_timesteps,
#     314         progress_bar=progress_bar,
#     315     )
#
# File c:\Users\sasia\envs\RL\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:271, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     268         self.logger.record("time/total_timesteps", self.num_timesteps, exclude="tensorboard")
#     269         self.logger.dump(step=self.num_timesteps)
# --> 271     self.train()
#     273 callback.on_training_end()
#     275 return self
#
# File c:\Users\sasia\envs\RL\lib\site-packages\stable_baselines3\ppo\ppo.py:210, in PPO.train(self)
#     207 if self.use_sde:
#     208     self.policy.reset_noise(self.batch_size)
# --> 210 values, log_prob, entropy = self.policy.evaluate_actions(rollout_data.observations, actions)
#     211 values = values.flatten()
#     212 # Normalize advantage
#
# File c:\Users\sasia\envs\RL\lib\site-packages\stable_baselines3\common\policies.py:698, in ActorCriticPolicy.evaluate_actions(self, obs, actions)
#     696 distribution = self._get_action_dist_from_latent(latent_pi)
#     697 log_prob = distribution.log_prob(actions)
# --> 698 values = self.value_net(latent_vf)
#     699 entropy = distribution.entropy()
#     700 return values, log_prob, entropy
#
# File c:\Users\sasia\envs\RL\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File c:\Users\sasia\envs\RL\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File c:\Users\sasia\envs\RL\lib\site-packages\torch\nn\modules\linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
learner.save("simple_PPO_model")
del learner

# %%
# multi-instance example

import rlgym
from stable_baselines3 import PPO

# Make the default rlgym environment
env = rlgym.make(use_injector=True)

# Initialize PPO from stable_baselines3
model = PPO("MlpPolicy", env=env, verbose=1)

# Train our agent!

# Here we import the Match object and our multi-instance wrapper
from rlgym.envs import Match
from rlgym_tools.sb3_utils import SB3MultipleInstanceEnv

# Since we can't use the normal rlgym.make() function, we need to import all the default configuration objects to give to our Match.
from rlgym.utils.reward_functions import DefaultReward
from rlgym.utils.obs_builders import DefaultObs
from rlgym.utils.state_setters import DefaultState
from rlgym.utils.action_parsers import DefaultAction
from rlgym.utils.terminal_conditions.common_conditions import TimeoutCondition

# Finally, we import the SB3 implementation of PPO.
from stable_baselines3.ppo import PPO

# This is the function we need to provide to our SB3MultipleInstanceEnv to construct a match. Note that this function MUST return a Match object.
def get_match():
    
    # Here we configure our Match. If you want to use custom configuration objects, make sure to replace the default arguments here with instances of the objects you want.
    return Match(        
        reward_function=DefaultReward(),
        terminal_conditions=[TimeoutCondition(225)],
        obs_builder=DefaultObs(),
        state_setter=DefaultState(),
        action_parser=DefaultAction(),
        spawn_opponents=True,
    )
    

#If we want to spawn new processes, we have to make sure our program starts in a proper Python entry point.
if __name__ == "__main__":
    """
        Now all we have to do is make an instance of the SB3MultipleInstanceEnv and pass it our get_match function, the number of instances we'd like to open, and how long it should wait between instances.
        This wait_time argument is important because if multiple Rocket League clients are opened in quick succession, they will cause each other to crash. The exact reason this happens is unknown to us,
        but the easiest solution is to delay for some period of time between launching clients. The amount of required delay will depend on your hardware, so make sure to change this number if your Rocket League
        clients are crashing before they fully launch.
    """
    env = SB3MultipleInstanceEnv(match_func_or_matches=get_match, num_instances=2, wait_time=20)
    learner = PPO(policy="MlpPolicy", env=env, verbose=1)
    learner.learn(1_000_000)

model.learn(total_timesteps=int(1e6))
# Out:
# Version 1.2.2
#
#     - Fixed max python version
#
#
# Launching Rocket League, make sure bakkesmod is running.
# Launched Epic version
# Executing injector...
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
